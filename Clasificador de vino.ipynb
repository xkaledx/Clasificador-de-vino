# %%
import pandas as pd
import numpy as np

# %%
wine_df = pd.read_csv('https://raw.githubusercontent.com/xkaledx/123/main/winequality.csv')

# %%
wine_df.head()
# Out:
#    acidez fija  acidez volátil  ácido cítrico  azúcares residuales  cloruros  \
# 0          7.4            0.70           0.00                  1.9     0.076
# 1          7.8            0.88           0.00                  2.6     0.098
# 2          7.8            0.76           0.04                  2.3     0.092
# 3         11.2            0.28           0.56                  1.9     0.075
# 4          7.4            0.70           0.00                  1.9     0.076
#
#    dióxido de azufre libre  dióxido de azufre total  densidad     pH  \
# 0                     11.0                     34.0     0.9978  3.51
# 1                     25.0                     67.0     0.9968  3.20
# 2                     15.0                     54.0     0.9970  3.26
# 3                     17.0                     60.0     0.9980  3.16
# 4                     11.0                     34.0     0.9978  3.51
#
#    sulfatos  alcohol   Calidad
# 0      0.56       9.4        5
# 1      0.68       9.8        5
# 2      0.65       9.8        5
# 3      0.58       9.8        6
# 4      0.56       9.4        5

# %%
wine_df.Calidad = np.where(wine_df.Calidad >= 6,'Good', 'Bad')

# %%
wine_df.head()
# Out:
#    acidez fija  acidez volátil  ácido cítrico  azúcares residuales  cloruros  \
# 0          7.4            0.70           0.00                  1.9     0.076
# 1          7.8            0.88           0.00                  2.6     0.098
# 2          7.8            0.76           0.04                  2.3     0.092
# 3         11.2            0.28           0.56                  1.9     0.075
# 4          7.4            0.70           0.00                  1.9     0.076
#
#    dióxido de azufre libre  dióxido de azufre total  densidad     pH  \
# 0                     11.0                     34.0     0.9978  3.51
# 1                     25.0                     67.0     0.9968  3.20
# 2                     15.0                     54.0     0.9970  3.26
# 3                     17.0                     60.0     0.9980  3.16
# 4                     11.0                     34.0     0.9978  3.51
#
#    sulfatos  alcohol  Calidad
# 0      0.56       9.4     Bad
# 1      0.68       9.8     Bad
# 2      0.65       9.8     Bad
# 3      0.58       9.8    Good
# 4      0.56       9.4     Bad

# %%
from pycaret.classification import *
exp_clf01 = setup(data = wine_df, target = 'Calidad', session_id = 123)
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target           Calidad
# 2                              Target Type            Binary
# 3                            Label Encoded   Bad: 0, Good: 1
# 4                            Original Data        (1599, 12)
# 5                           Missing Values             False
# 6                         Numeric Features                11
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set        (1119, 11)
# 12                    Transformed Test Set         (480, 11)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              5a82
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44                              Clustering             False
# 45                    Clustering Iteration              None
# 46                     Polynomial Features             False
# 47                       Polynomial Degree              None
# 48                    Trignometry Features             False
# 49                    Polynomial Threshold              None
# 50                          Group Features             False
# 51                       Feature Selection             False
# 52                Feature Selection Method           classic
# 53            Features Selection Threshold              None
# 54                     Feature Interaction             False
# 55                           Feature Ratio             False
# 56                   Interaction Threshold              None
# 57                           Fix Imbalance             False
# 58                    Fix Imbalance Method             SMOTE
# 2021-05-23 02:19:06.561 INFO    logs: create_model_container: 0
# 2021-05-23 02:19:06.563 INFO    logs: master_model_container: 0
# 2021-05-23 02:19:06.567 INFO    logs: display_container: 1
# 2021-05-23 02:19:06.580 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='Calidad',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_stra...
#                 ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='Calidad')),
#                 ('fix_perfect', Remove_100(target='Calidad')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# 2021-05-23 02:19:06.581 INFO    logs: setup() succesfully completed......................................

# %%
best = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.8222  0.8973  0.8384  0.8357
# et                 Extra Trees Classifier    0.8159  0.9044  0.8319  0.8302
# lightgbm  Light Gradient Boosting Machine    0.8132  0.8849  0.8204  0.8346
# gbc          Gradient Boosting Classifier    0.7855  0.8593  0.7990  0.8071
# ridge                    Ridge Classifier    0.7569  0.0000  0.7497  0.7910
# lr                    Logistic Regression    0.7507  0.8177  0.7480  0.7825
# lda          Linear Discriminant Analysis    0.7489  0.8173  0.7513  0.7779
# dt               Decision Tree Classifier    0.7444  0.7411  0.7809  0.7568
# nb                            Naive Bayes    0.7418  0.8043  0.7646  0.7615
# ada                  Ada Boost Classifier    0.7363  0.8126  0.7645  0.7548
# qda       Quadratic Discriminant Analysis    0.7328  0.8032  0.8072  0.7296
# knn                K Neighbors Classifier    0.6398  0.6951  0.6673  0.6688
# svm                   SVM - Linear Kernel    0.5996  0.0000  0.7302  0.6696
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.8364  0.6416  0.6429     0.551
# et        0.8306  0.6290  0.6299     0.504
# lightgbm  0.8266  0.6242  0.6257     0.125
# gbc       0.8018  0.5682  0.5703     0.198
# ridge     0.7688  0.5131  0.5151     0.019
# lr        0.7642  0.5000  0.5015     0.443
# lda       0.7635  0.4960  0.4974     0.019
# dt        0.7684  0.4835  0.4841     0.020
# nb        0.7621  0.4798  0.4811     0.017
# ada       0.7578  0.4684  0.4711     0.127
# qda       0.7661  0.4563  0.4603     0.017
# knn       0.6667  0.2748  0.2761     0.119
# svm       0.6464  0.1716  0.1888     0.017
# 2021-05-23 02:19:38.542 INFO    logs: create_model_container: 13
# 2021-05-23 02:19:38.548 INFO    logs: master_model_container: 13
# 2021-05-23 02:19:38.551 INFO    logs: display_container: 2
# 2021-05-23 02:19:38.555 INFO    logs: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)
# 2021-05-23 02:19:38.558 INFO    logs: compare_models() succesfully completed......................................

# %%
exp_clf102 = setup(data = wine_df, target = 'Calidad', session_id=123,
                  normalize = True, 
                  transformation = True)
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target           Calidad
# 2                              Target Type            Binary
# 3                            Label Encoded   Bad: 0, Good: 1
# 4                            Original Data        (1599, 12)
# 5                           Missing Values             False
# 6                         Numeric Features                11
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set        (1119, 11)
# 12                    Transformed Test Set         (480, 11)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              b565
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize              True
# 30                        Normalize Method            zscore
# 31                          Transformation              True
# 32                   Transformation Method       yeo-johnson
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44                              Clustering             False
# 45                    Clustering Iteration              None
# 46                     Polynomial Features             False
# 47                       Polynomial Degree              None
# 48                    Trignometry Features             False
# 49                    Polynomial Threshold              None
# 50                          Group Features             False
# 51                       Feature Selection             False
# 52                Feature Selection Method           classic
# 53            Features Selection Threshold              None
# 54                     Feature Interaction             False
# 55                           Feature Ratio             False
# 56                   Interaction Threshold              None
# 57                           Fix Imbalance             False
# 58                    Fix Imbalance Method             SMOTE
# 2021-05-23 02:20:26.424 INFO    logs: create_model_container: 0
# 2021-05-23 02:20:26.426 INFO    logs: master_model_container: 0
# 2021-05-23 02:20:26.429 INFO    logs: display_container: 1
# 2021-05-23 02:20:26.449 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='Calidad',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_stra...
#                                                   random_state_quantile=123,
#                                                   target='Calidad')),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='Calidad')),
#                 ('fix_perfect', Remove_100(target='Calidad')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# 2021-05-23 02:20:26.452 INFO    logs: setup() succesfully completed......................................

# %%
best = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.8222  0.8976  0.8351  0.8380
# et                 Extra Trees Classifier    0.8222  0.9028  0.8434  0.8324
# lightgbm  Light Gradient Boosting Machine    0.8141  0.8835  0.8237  0.8337
# gbc          Gradient Boosting Classifier    0.7873  0.8596  0.7991  0.8095
# lr                    Logistic Regression    0.7525  0.8201  0.7727  0.7719
# qda       Quadratic Discriminant Analysis    0.7507  0.8123  0.7760  0.7679
# ridge                    Ridge Classifier    0.7498  0.0000  0.7595  0.7750
# lda          Linear Discriminant Analysis    0.7498  0.8215  0.7595  0.7750
# dt               Decision Tree Classifier    0.7444  0.7413  0.7793  0.7578
# nb                            Naive Bayes    0.7373  0.8128  0.7119  0.7854
# ada                  Ada Boost Classifier    0.7363  0.8127  0.7645  0.7548
# knn                K Neighbors Classifier    0.7328  0.8023  0.7841  0.7407
# svm                   SVM - Linear Kernel    0.7247  0.0000  0.7364  0.7552
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.8359  0.6418  0.6430     0.562
# et        0.8373  0.6413  0.6425     0.506
# lightgbm  0.8275  0.6260  0.6277     0.083
# gbc       0.8030  0.5720  0.5741     0.198
# lr        0.7711  0.5015  0.5032     0.020
# qda       0.7711  0.4972  0.4985     0.019
# ridge     0.7659  0.4972  0.4990     0.015
# lda       0.7659  0.4972  0.4990     0.018
# dt        0.7680  0.4837  0.4844     0.019
# nb        0.7461  0.4753  0.4787     0.017
# ada       0.7578  0.4684  0.4711     0.125
# knn       0.7605  0.4589  0.4622     0.118
# svm       0.7430  0.4466  0.4502     0.019
# 2021-05-23 02:20:58.134 INFO    logs: create_model_container: 13
# 2021-05-23 02:20:58.136 INFO    logs: master_model_container: 13
# 2021-05-23 02:20:58.139 INFO    logs: display_container: 2
# 2021-05-23 02:20:58.141 INFO    logs: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)
# 2021-05-23 02:20:58.144 INFO    logs: compare_models() succesfully completed......................................

# %%
et_model = create_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8304  0.9087  0.7869  0.8889  0.8348  0.6618  0.6670
# 1       0.8214  0.9164  0.8361  0.8361  0.8361  0.6400  0.6400
# 2       0.8482  0.9346  0.8525  0.8667  0.8595  0.6945  0.6946
# 3       0.8393  0.9041  0.8689  0.8413  0.8548  0.6749  0.6754
# 4       0.8393  0.8944  0.8852  0.8308  0.8571  0.6739  0.6757
# 5       0.8482  0.9253  0.8525  0.8667  0.8595  0.6945  0.6946
# 6       0.8214  0.8987  0.8689  0.8154  0.8413  0.6377  0.6393
# 7       0.7768  0.8697  0.8333  0.7692  0.8000  0.5484  0.5506
# 8       0.7768  0.8819  0.8000  0.7869  0.7934  0.5507  0.5508
# 9       0.8198  0.8944  0.8500  0.8226  0.8361  0.6362  0.6366
# Mean    0.8222  0.9028  0.8434  0.8324  0.8373  0.6413  0.6425
# SD      0.0248  0.0185  0.0291  0.0348  0.0224  0.0502  0.0501
# 2021-05-23 02:21:25.117 INFO    logs: create_model_container: 14
# 2021-05-23 02:21:25.120 INFO    logs: master_model_container: 14
# 2021-05-23 02:21:25.123 INFO    logs: display_container: 3
# 2021-05-23 02:21:25.126 INFO    logs: ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)
# 2021-05-23 02:21:25.129 INFO    logs: create_model() succesfully completed......................................

# %%
evaluate_model(et_model)
# Out:
# 2021-05-23 02:21:27.618 INFO    logs: Initializing evaluate_model()
# 2021-05-23 02:21:27.627 INFO    logs: evaluate_model(estimator=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False), fold=None, fit_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(et_model)
# Out:
# 2021-05-23 02:21:33.967 INFO    logs: Initializing predict_model()
# 2021-05-23 02:21:33.972 INFO    logs: predict_model(estimator=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False), probability_threshold=None, encoded_labels=False, raw_score=False, round=4, verbose=True, ml_usecase=MLUsecase.CLASSIFICATION, display=None)
# 2021-05-23 02:21:33.975 INFO    logs: Checking exceptions
# 2021-05-23 02:21:33.976 INFO    logs: Preloading libraries
# 2021-05-23 02:21:33.977 INFO    logs: Preparing display monitor
#                     Model  Accuracy    AUC  ...      F1   Kappa     MCC
# 0  Extra Trees Classifier    0.7938  0.886  ...  0.8085  0.5858  0.5881
#
# [1 rows x 8 columns]
#      acidez fija  acidez volátil  ácido cítrico  ...  Calidad  Label  Score
# 0       1.020588       -0.262337       0.879953  ...     Good   Good   0.88
# 1       0.803909        0.365825       0.069862  ...      Bad    Bad   0.95
# 2      -0.548073        1.883447      -0.893326  ...      Bad    Bad   0.79
# 3       0.107596       -1.862275       0.790671  ...     Good   Good   0.85
# 4      -0.094340       -0.848967      -0.143052  ...      Bad    Bad   0.62
# ..           ...             ...            ...  ...      ...    ...    ...
# 475    -0.548073       -0.140215       0.322091  ...     Good   Good   1.00
# 476     1.829654       -0.021461       1.097945  ...      Bad    Bad   1.00
# 477    -0.629808       -0.781026       0.222941  ...     Good   Good   1.00
# 478     0.936345       -1.341807       0.654237  ...     Good   Good   0.89
# 479     0.170978        0.520056      -0.035377  ...      Bad    Bad   1.00
#
# [480 rows x 14 columns]

# %%
save_model(et_model, model_name = 'extra_tree_model')
# Out:
# 2021-05-23 02:21:40.218 INFO    logs: Initializing save_model()
# 2021-05-23 02:21:40.222 INFO    logs: save_model(model=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False), model_name=extra_tree_model, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='Calidad',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_stra...
#                                                   random_state_quantile=123,
#                                                   target='Calidad')),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='Calidad')),
#                 ('fix_perfect', Remove_100(target='Calidad')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), verbose=True, kwargs={})
# 2021-05-23 02:21:40.224 INFO    logs: Adding model into prep_pipe
# 2021-05-23 02:21:40.298 INFO    logs: extra_tree_model.pkl saved in current working directory
# 2021-05-23 02:21:40.312 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='Calidad',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_stra...
#                  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                       class_weight=None, criterion='gini',
#                                       max_depth=None, max_features='auto',
#                                       max_leaf_nodes=None, max_samples=None,
#                                       min_impurity_decrease=0.0,
#                                       min_impurity_split=None,
#                                       min_samples_leaf=1, min_samples_split=2,
#                                       min_weight_fraction_leaf=0.0,
#                                       n_estimators=100, n_jobs=-1,
#                                       oob_score=False, random_state=123,
#                                       verbose=0, warm_start=False)]],
#          verbose=False)
# 2021-05-23 02:21:40.317 INFO    logs: save_model() succesfully completed......................................
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Calidad',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=-1,
#                                        oob_score=False, random_state=123,
#                                        verbose=0, warm_start=False)]],
#           verbose=False), 'extra_tree_model.pkl')
